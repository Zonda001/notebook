# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# ###  Data Science Tools and Ecosystem

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](attachment:2d57d546-7ec9-4396-9eef-b9140330ab61.png)

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:

# %% [markdown]
# ![image.png](attachment:b5aa054e-3b54-4c8c-92e7-77dd705ae7c6.png)

# %% [markdown]
# ## List Data Science Libraries

# %% [markdown]
# ![image.png](attachment:6d62412f-ab01-4e47-ae9f-ed9d9c15fe56.png)

# %% [markdown]
# ## Create a Table for Data Science Tools

# %% [markdown]
# ![image.png](attachment:eab8d9b8-77e7-4038-a01e-f7fa1e3393ba.png)

# %% [markdown]
# # Introduce Arithmetic Expression Examples

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:c945f50f-8b18-49dd-8b97-9d808ff26b48.png)

# %% [markdown]
# # Multiply and Add Numbers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:97674968-ef90-4622-bea2-19802be52011.png)

# %% [markdown]
# # Convert Minutes to Hours

# %%
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](attachment:189b8314-6377-4339-8fad-6dad53fc4dd6.png)

# %% [markdown]
#  # List Objectives

# %%
- List popular languages for Data Science
- Introduce commonly used libraries in Data Science
- Show examples of basic arithmetic operations in Python

# %% [markdown]
# ![image.png](attachment:21f24ff0-78a9-46af-bae0-d34659a2ec81.png)

# %% [markdown]
# ## Author’s Details

# %%
Sidorov Denys

# %% [markdown]
# ![image.png](attachment:c1b1d39e-6171-4dbe-aa39-0bd3e574829d.png)
